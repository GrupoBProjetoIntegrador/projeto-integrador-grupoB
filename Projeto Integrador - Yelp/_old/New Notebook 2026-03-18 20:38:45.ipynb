# %%
#@title Importação de pacotes
import requests
import zipfile
import io
import pandas as pd
from datetime import datetime, date, timedelta
from pandas.tseries.offsets import BMonthBegin, BMonthEnd, MonthEnd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
import json
import os

# %%
import requests

url = "https://www.kaggle.com/api/v1/datasets/download/yelp-dataset/yelp-dataset"

response = requests.get(url, stream=True)

chunk_size = 450 * 1024 * 1024  # 450 MB
dbutils.fs.mkdirs("dbfs:/FileStore/yelp/")
with open("/dbfs/FileStore/yelp/yelp.zip", "wb") as f:
    for chunk in response.iter_content(chunk_size=chunk_size):
        if chunk:
            f.write(chunk)

print("Download concluído!")
