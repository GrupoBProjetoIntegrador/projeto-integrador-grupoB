# %%
Gerando perguntas específicas: 

1- Descobrir os 10 melhores restaurantes por segmento e localidade (usar rating yelp).
Possível objetivo do Marketing: oportunidades de expansão dos melhores restaurantes)
(merge dos dashs de região e marketing)
    Filtro de categoria, cidade e estado.

2- Identificar qual dia da semana tem menos visitas por segmento e localidade.
2- Identificar os meses e/ou dias da semana com menos visitas por segmento e localidade.
    Filtro de categoria, ano, mes, 

Possível objetivo do Marketing: campanhas para impulso de vendas, por exemplo: cupom promocional em dias de menor movimento)

3- Identificar os estabelecimentos com reviews suspeitas de fraudes;
Possível objetivo: punição na plataforma yelp)
    Filtro de data, 

4- Identificar os top users da plataforma
Possível objetivo: contrato de influência para criação de conteúdo;
    Filtro de estado
