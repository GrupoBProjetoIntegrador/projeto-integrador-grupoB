# %%
RAW_DATA_PATH = "/Workspace/Users/jefferson.da.silva.almeida@usp.br/Projeto Integrador - Yelp/landing_zone_kaggle_api"

df = spark.read.json(f"{RAW_DATA_PATH}/yelp_academic_dataset_business.json")

# %%
display(df)
