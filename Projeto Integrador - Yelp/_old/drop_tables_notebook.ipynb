# %%
spark.sql("drop table workspace.default.bronze_yelp_academic_dataset_user")
spark.sql("drop table workspace.default.bronze_yelp_academic_dataset_checkin")
spark.sql("drop table workspace.default.bronze_yelp_academic_dataset_review")
spark.sql("drop table workspace.default.bronze_yelp_academic_dataset_tip")
